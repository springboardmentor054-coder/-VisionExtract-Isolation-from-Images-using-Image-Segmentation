# %%
# !pip install opencv-python matplotlib numpy torch torchvision kaggle
# Out:
# Requirement already satisfied: opencv-python in c:\users\sreel\anaconda3\lib\site-packages (4.10.0.82)
# Requirement already satisfied: matplotlib in c:\users\sreel\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy in c:\users\sreel\anaconda3\lib\site-packages (2.2.4)
# Requirement already satisfied: torch in c:\users\sreel\anaconda3\lib\site-packages (1.12.1)
# Collecting torchvision
#   Using cached torchvision-0.25.0-cp310-cp310-win_amd64.whl (3.7 MB)
# Collecting kaggle
#   Using cached kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: typing_extensions in c:\users\sreel\anaconda3\lib\site-packages (from torch) (4.12.2)
# Collecting torch
#   Using cached torch-2.10.0-cp310-cp310-win_amd64.whl (113.7 MB)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Requirement already satisfied: jinja2 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: filelock in c:\users\sreel\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (2022.11.0)
# Requirement already satisfied: tqdm in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (4.64.1)
# Requirement already satisfied: charset-normalizer in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (2.0.4)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (65.6.3)
# Requirement already satisfied: idna in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (3.4)
# Requirement already satisfied: text-unidecode in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: bleach in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (1.26.14)
# Requirement already satisfied: six>=1.10 in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: requests in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (2.28.1)
# Requirement already satisfied: python-slugify in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: protobuf in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: webencodings in c:\users\sreel\anaconda3\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sreel\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sreel\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: colorama in c:\users\sreel\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Installing collected packages: sympy, torch, kaggle, torchvision
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed kaggle-1.7.4.5 sympy-1.14.0 torch-2.10.0 torchvision-0.25.0

# %%
# !pip install opencv-python matplotlib numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\sreel\anaconda3\lib\site-packages (4.10.0.82)
# Requirement already satisfied: matplotlib in c:\users\sreel\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy in c:\users\sreel\anaconda3\lib\site-packages (2.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: six>=1.5 in c:\users\sreel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install numpy pandas matplotlib opencv-python pillow torch torchvision pycocotools
# Out:
# Requirement already satisfied: numpy in c:\users\sreel\anaconda3\lib\site-packages (2.2.4)
# Requirement already satisfied: pandas in c:\users\sreel\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\sreel\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: opencv-python in c:\users\sreel\anaconda3\lib\site-packages (4.10.0.82)
# Requirement already satisfied: pillow in c:\users\sreel\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: torch in c:\users\sreel\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\users\sreel\anaconda3\lib\site-packages (0.25.0)
# Collecting pycocotools
#   Downloading pycocotools-2.0.11-cp310-cp310-win_amd64.whl (80 kB)
#      ---------------------------------------- 80.2/80.2 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\sreel\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sreel\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: filelock in c:\users\sreel\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (2022.11.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sreel\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\sreel\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sreel\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sreel\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.11

# %%
# !pip install numpy==1.26.4 matplotlib pillow pycocotools opencv-python
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\users\sreel\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\sreel\anaconda3\lib\site-packages (3.10.8)
# Requirement already satisfied: pillow in c:\users\sreel\anaconda3\lib\site-packages (9.4.0)
# Requirement already satisfied: pycocotools in c:\users\sreel\anaconda3\lib\site-packages (2.0.11)
# Requirement already satisfied: opencv-python in c:\users\sreel\anaconda3\lib\site-packages (4.10.0.82)
# Requirement already satisfied: packaging>=20.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=3 in c:\users\sreel\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\sreel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from pycocotools.coco import COCO

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
dataset_path = r"C:\Users\sreel\Desktop\VisionExtract\supervisely_person_clean\person_segmentation"

image_folder = os.path.join(dataset_path, "images")

mask_folder = os.path.join(dataset_path, "masks")

print("Images:", len(os.listdir(image_folder)))
print("Masks:", len(os.listdir(mask_folder)))
# Out:
# Images: 2667
# Masks: 2667

# %%
image_files = sorted(os.listdir(image_folder))

image_files = image_files[55:60]

print(image_files)
# Out:
# ['ds11_pexels-photo-698925.png', 'ds11_pexels-photo-717208.png', 'ds11_pexels-photo-751242.png', 'ds11_pexels-photo-756555.png', 'ds11_pexels-photo-764340.png']

# %%
for i, file_name in enumerate(image_files):

    image_path = os.path.join(image_folder, file_name)

    mask_path = os.path.join(mask_folder, file_name)

    # Load image

    image = Image.open(image_path).convert("RGB")

    image_np = np.array(image)

    # Load mask

    mask = Image.open(mask_path).convert("L")

    mask_np = np.array(mask)

    # Convert mask to binary

    binary_mask = (mask_np > 0).astype(np.uint8)

    # Isolate subject

    isolated = image_np * binary_mask[:, :, None]

    # Show results

    plt.figure(figsize=(18,5))

    plt.subplot(1,3,1)
    plt.imshow(image)
    plt.title(f"Original Image {i+1}")
    plt.axis("off")

    plt.subplot(1,3,2)
    plt.imshow(binary_mask, cmap="gray")
    plt.title(f"Mask {i+1}")
    plt.axis("off")

    plt.subplot(1,3,3)
    plt.imshow(isolated)
    plt.title(f"Isolated Subject {i+1}")
    plt.axis("off")

    plt.show()
